# %% [markdown]
# # 01 EDA
#
# Explore weekly stats and basic distributions for props modeling.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nfl_data_py as nfl

weekly = nfl.import_weekly_data(years=[2024])
weekly['receiving_yards'].hist(bins=50)
plt.title('Receiving Yards Distribution (2024)')
plt.show()
